# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import pickle

# %%
data = {
"text": [


    # ===================== FAKE INTERNSHIPS (100) =====================
    "Pay registration fee of 1500 to confirm your internship position immediately",
    "Send money to confirm your internship slot",
    "Training fee required before joining internship",
    "Pay now to secure your seat limited offer",
    "Registration amount needed for internship confirmation",
    "Pay 2000 for internship selection",
    "Internship available pay fee and join immediately",
    "Send payment screenshot to HR for confirmation",
    "No interview direct selection after payment",
    "Urgent hiring pay fee to apply now",
    "Work from home job pay first then start",
    "Pay training fee and get internship guarantee",
    "Limited seats hurry up pay now",
    "Guaranteed placement after paying course fee",
    "Click link and pay amount to confirm selection",
    "Internship with refundable deposit required",
    "Telegram HR for quick selection and payment details",
    "High stipend internship but pay security deposit",
    "Instant joining after payment confirmation",
    "Pay first month fee for internship access",
    "Fake company asking for joining fee",
    "Internship requires advance payment",
    "Pay registration fee before interview",
    "Send money to reserve internship slot",
    "Online internship pay to enroll",
    "Pay fees to unlock internship details",
    "Selection based on payment not interview",
    "Pay now and start immediately",
    "Internship access after payment only",
    "Training and internship combo pay now",
    "Pay to receive internship certificate",
    "No process just payment required",
    "Easy internship pay small fee",
    "Internship confirmation requires payment",
    "Apply fast and pay to secure job",
    "Direct internship no interview pay fee",
    "Pay security amount refundable later",
    "Internship selection fee mandatory",
    "Send payment and join instantly",
    "Pay for verification to get internship",
    "Fee required for background check",
    "Internship with hidden charges pay now",
    "Payment required before HR call",
    "No experience needed pay and start",
    "Pay registration charges for interview",
    "Fake HR asking for payment",
    "Internship via WhatsApp pay fee",
    "Pay to get shortlisted",
    "Selection guaranteed after payment",
    "Pay training amount to join",
    "Payment needed to activate internship",
    "Join internship after paying fee",
    "No resume required pay to apply",
    "Pay and get internship letter",
    "Fake internship asking for money",
    "Deposit amount required to start internship",
    "Pay joining fee immediately",
    "Internship available pay now limited time",
    "Fee needed to process application",
    "Pay application fee now",
    "Quick internship pay and join",
    "Internship slot confirmed after payment",
    "Send money for confirmation email",
    "Internship training requires fee payment",
    "Payment required to access company portal",
    "Fake internship offer pay first",
    "Internship selection depends on payment",
    "Pay to attend interview",
    "Apply now and pay registration",
    "Payment required for internship kit",
    "Pay now for onboarding process",
    "Internship requires payment for documents",
    "Fee needed for company ID creation",
    "Internship with payment requirement",
    "Send fee to join internship",
    "Payment required before starting work",
    "Internship approval after payment",
    "Pay fee to get internship certificate",
    "Fake job internship pay now",
    "Pay for internship opportunity",
    "Payment needed for HR verification",
    "Pay to get joining confirmation",
    "Internship offer after fee payment",
    "Pay to unlock internship benefits",
    "Internship process starts after payment",
    "Pay and receive offer letter",
    "Internship requires advance fee",
    "Payment required to secure position",
    "Internship available after fee submission",
    "Pay before interview process",
    "Fee required for internship entry",
    "Send money to HR for joining",
    "Internship confirmation after fee payment",
    "Pay to get internship access",
    "Fake internship pay fee now",
    "Payment needed to proceed further",

    # ===================== REAL INTERNSHIPS (100) =====================
    "Internship opportunity at Infosys with proper interview process",
    "Apply through official company website with resume submission",
    "Selection based on technical test and HR interview",
    "No registration fee required purely merit based selection",
    "Internship with structured training and real project exposure",
    "Work from office internship with stipend and mentorship",
    "Apply via LinkedIn official job listing",
    "Company will contact shortlisted candidates through official email",
    "Candidates must complete assignment before final selection",
    "Official company email domain will be used for communication",
    "Internship with clear job description and responsibilities",
    "Recruitment includes online test and interview rounds",
    "Stipend based internship with no upfront payment",
    "Apply through company careers portal",
    "Transparent hiring process with proper verification",
    "Paid internship with monthly stipend and certificate",
    "Internship with salary and no registration fee",
    "Company offers stipend based internship program",
    "Apply for internship no payment required only interview",
    "Work from home internship with fixed stipend",
    "Internship with mentorship and learning support",
    "Selection process includes resume screening and interview",
    "Internship opportunity with real time projects",
    "Candidates selected based on skills and performance",
    "Official internship with HR interview and training",
    "Internship with certificate and stipend provided",
    "Apply through verified job portal",
    "Internship with clear hiring steps and no hidden fees",
    "No fee internship with proper onboarding process",
    "Internship opportunity with structured evaluation",
    "Work from office internship with professional guidance",
    "Internship with performance based stipend",
    "Company provides internship without any payment",
    "Internship with real work experience and team support",
    "Apply through official recruitment page",
    "Internship includes training and evaluation",
    "Candidates shortlisted through proper hiring process",
    "Internship with defined roles and responsibilities",
    "No payment required for internship application",
    "Internship based on skills and interview performance",

    # 🔥 CONTEXT FIXERS (VERY IMPORTANT)
    "Paid internship with stipend no fee required",
    "Internship with good salary and proper hiring process",
    "Do not pay any fee this internship is completely free",
    "Internship with stipend but requires interview process",
    "Company provides paid internship no upfront cost",

    # MORE REAL VARIATIONS
    "Internship with stipend and no registration charges",
    "Apply for internship through official HR email",
    "Internship with transparent hiring process",
    "No hidden charges internship with certificate",
    "Internship with real company projects",
    "Selection based on interview not payment",
    "Internship with clear communication and offer letter",
    "Company offers free internship with mentorship",
    "Internship without any fee or payment",
    "Apply through verified company website",
    "Internship includes training and certificate",
    "Work from home internship with no fee",
    "Internship with fixed stipend and HR process",
    "Candidates selected after interview rounds",
    "Internship with no payment and real experience",
    "Internship program with official documentation",
    "Apply through LinkedIn or company portal",
    "Internship without charges and proper process",
    "Internship with skill based selection",
    "No fee required internship with certificate",
    "Company provides internship with stipend and guidance",
    "Internship with official communication and email",
    "Apply without any payment for internship",
    "Internship with real work and supervision",
    "Internship selection based on merit",
    "No payment required apply freely",
    "Internship with HR verification and onboarding",
    "Company internship without hidden charges",
    "Internship includes real time tasks and mentorship",
    "Internship with stipend and evaluation process",
    "No fee internship apply through official link",
    "Internship with clear job role and support",
    "Internship opportunity with structured hiring",
    "Apply through official platform only",
    "Internship with no upfront cost and proper training",
    "Internship includes learning and project work",
    "Company internship with no payment requirement",
    "Internship with interview and onboarding process",
    "Internship without fee and proper hiring steps",
    "Internship with real company exposure"
],

"label": [
    *([1]*100),
    *([0]*100)
]


}


df = pd.DataFrame(data)
df.head()

# %%
# Split data
X_train, X_test, y_train, y_test = train_test_split(df["text"], df["label"], test_size=0.2)

# Convert text → numbers
vectorizer = TfidfVectorizer(stop_words='english', ngram_range=(1,2))
X_train_vec = vectorizer.fit_transform(X_train)
X_test_vec = vectorizer.transform(X_test)

# Train model
model = LogisticRegression()
model.fit(X_train_vec, y_train)

# Accuracy check
y_pred = model.predict(X_test_vec)
print("Accuracy:", accuracy_score(y_test, y_pred))

# %%
pickle.dump(model, open("model.pkl", "wb"))
pickle.dump(vectorizer, open("vectorizer.pkl", "wb"))

print("Model and vectorizer saved successfully!")

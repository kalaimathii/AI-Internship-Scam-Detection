# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report
import pickle

# %%
texts = []
labels = []

fake_samples = [
"Pay registration fee to confirm internship",
"Send money to secure your internship slot",
"Training fee required before joining",
"Pay now for guaranteed internship",
"Registration charges mandatory",
"Pay 2000 to get internship",
"Internship available pay and join",
"Send payment screenshot to HR",
"No interview direct selection after payment",
"Urgent hiring pay fee now",
"Work from home job pay first",
"Pay training fee and get placement",
"Limited seats pay now",
"Guaranteed internship after payment",
"Click link and pay amount",
"Refundable deposit required",
"Telegram HR for payment details",
"High stipend but pay deposit",
"Instant joining after payment",
"Pay first month fee",
"Fake company asking payment",
"Internship requires payment",
"Pay before interview",
"Send money to reserve slot",
"Online internship pay to enroll",
"Unlock internship after payment",
"Selection based on payment",
"Pay and start immediately",
"Internship access after fee",
"Training + internship pay now",
"Pay to receive certificate",
"No process only payment",
"Easy internship pay small fee",
"Internship confirmation requires fee",
"Apply fast pay to secure job",
"Direct internship pay fee",
"Security deposit required",
"Internship selection fee",
"Send payment and join",
"Pay for verification",
"Background check fee",
"Hidden charges internship",
"Payment before HR call",
"No experience pay and start",
"Pay registration for interview",
"WhatsApp HR asking payment",
"Pay to get shortlisted",
"Guaranteed after payment",
"Pay training amount",
"Payment to activate internship",
"Join after paying fee",

# extra 50 diverse fake
"Pay application fee for internship approval",
"Internship requires onboarding charges",
"Send fee to get offer letter",
"Payment required to unlock dashboard",
"Pay to receive internship ID",
"Fee required for documentation",
"Internship entry fee mandatory",
"Submit payment to continue process",
"HR demands payment for selection",
"Processing fee required",
"Internship with joining charges",
"Pay to attend interview",
"Fee required for training kit",
"Pay to access internship portal",
"Fake internship asking deposit",
"Security amount required to join",
"Pay verification fee",
"Internship slot blocked until payment",
"Application locked pay to continue",
"Internship activation fee",
"Pay for company ID",
"Pay to receive onboarding email",
"Training fee compulsory",
"Pay internship service charges",
"Fee needed for approval",
"Internship license fee",
"HR asking for advance payment",
"Pay to start internship work",
"Payment needed for assignment access",
"Internship locked until fee paid",
"Pay and unlock internship details",
"Apply and pay for faster selection",
"Express internship pay extra fee",
"Premium internship requires payment",
"Pay to upgrade internship",
"Internship subscription fee",
"Monthly internship fee required",
"Pay to get internship confirmation",
"Internship pass fee",
"Pay to get HR contact",
"Unlock interview after payment",
"Internship verification charges",
"Pay for document approval",
"Internship booking fee",
"Fee to secure internship seat",
"Payment required for joining letter",
"Pay to receive internship materials",
"Internship requires fee clearance",
"Processing payment needed"
]

texts.extend(fake_samples)
labels.extend([1]*len(fake_samples))

# %%
genuine_samples = [
"Internship opportunity with proper interview process",
"Apply through official website",
"Selection based on test and interview",
"No registration fee required",
"Structured internship with training",
"Work from office with stipend",
"Apply via LinkedIn",
"Official email communication",
"Assignment before selection",
"Company domain email used",
"Clear job description",
"Interview rounds included",
"Stipend based internship",
"Apply via careers portal",
"Transparent hiring process",
"Paid internship with stipend",
"Internship with salary",
"Company offers stipend",
"No payment required apply freely",
"Work from home with stipend",
"Mentorship and guidance provided",
"Selection based on skills",
"Real time project internship",
"Candidates selected by performance",
"Official HR interview",
"Certificate and stipend provided",
"Verified job portal application",
"No hidden fees",
"Proper onboarding process",
"Structured evaluation",
"Professional work environment",
"Performance based stipend",
"No payment internship",
"Real work experience",
"Official recruitment page",
"Training included internship",
"Proper hiring process",
"Defined roles and responsibilities",
"No payment required",
"Merit based selection",

# extra 60 diverse genuine
"Internship with real company projects",
"Internship with technical training",
"Opportunity to work with team",
"Learning based internship program",
"Company sponsored internship",
"Official internship documentation",
"Internship with evaluation rounds",
"Skill based internship selection",
"Internship through verified HR",
"Company provides training resources",
"Internship includes project work",
"Apply through official platform",
"Internship with professional mentorship",
"Real industry exposure internship",
"Internship with structured onboarding",
"Internship through college placement cell",
"Company offers hands-on experience",
"Internship with certification",
"Internship with project submission",
"Official internship offer letter",
"Internship with reporting manager",
"Internship includes weekly tasks",
"Internship with performance review",
"Internship with feedback sessions",
"Internship with career growth",
"Internship through official channels",
"Internship includes skill development",
"Internship with real tasks",
"Internship without hidden charges",
"Internship with HR onboarding",
"Internship with email communication",
"Internship with proper schedule",
"Internship with attendance tracking",
"Internship with official guidelines",
"Internship through verified company",
"Internship with industry mentors",
"Internship with structured learning",
"Internship with job exposure",
"Internship with daily assignments",
"Internship with company supervision",
"Internship with proper process",
"Internship with offer letter",
"Internship through official HR email",
"Internship with no upfront cost",
"Internship with job training",
"Internship with reporting system",
"Internship with defined workflow",
"Internship with proper selection",
"Internship with real clients",
"Internship with work tracking",
"Internship with team collaboration",
"Internship with career support",
"Internship with resume building",
"Internship with project guidance",
"Internship with structured modules",
"Internship with evaluation system",
"Internship with learning outcomes",
"Internship with certification process",
"Internship with official communication"
]

texts.extend(genuine_samples)
labels.extend([0]*len(genuine_samples))

# %%
context_samples = [
"Paid internship no fee required",
"Internship with stipend not payment from student",
"Company pays interns",
"No fee internship with salary",
"Internship without payment required",
"Paid internship with onboarding",
"Interns receive stipend monthly",
"Company provides salary not asking money",
"Internship with stipend and no fee",
"No registration fee internship",
"Internship is free with stipend",
"Company pays student interns",
"Paid internship program no cost",
"Internship with salary benefits",
"No payment required for paid internship",
"Internship with stipend and training",
"Company funded internship",
"Internship where students are paid",
"Internship includes salary",
"Internship with no charges",

# extra 40
"Paid internship with HR process",
"Internship stipend provided monthly",
"Internship salary credited",
"Internship with company payment",
"Internship includes stipend support",
"Internship with financial benefits",
"Internship payment provided",
"Internship includes monthly salary",
"Internship is paid by company",
"Internship stipend no fee",
"Internship salary based",
"Internship paid program",
"Internship with compensation",
"Internship payment not required from student",
"Internship salary included",
"Internship stipend structure",
"Internship includes allowance",
"Internship paid training",
"Internship with financial support",
"Internship includes stipend benefits",
"Internship salary system",
"Internship compensation model",
"Internship paid opportunity",
"Internship with stipend package",
"Internship with earning opportunity",
"Internship stipend system",
"Internship with company payment model",
"Internship includes salary credit",
"Internship with income opportunity",
"Internship stipend program",
"Internship with financial growth",
"Internship salary benefits",
"Internship paid experience",
"Internship with earning model",
"Internship includes salary training",
"Internship paid exposure",
"Internship with stipend offer",
"Internship with company funding",
"Internship includes compensation plan",
"Internship paid learning"
]

texts.extend(context_samples)
labels.extend([0]*len(context_samples))

# %%
df = pd.DataFrame({
    "text": texts,
    "label": labels
})

print("Total samples:", len(df))
df.head()
# Out:
# Total samples: 259
#                                          text  label
# 0  Pay registration fee to confirm internship      1
# 1   Send money to secure your internship slot      1
# 2        Training fee required before joining      1
# 3           Pay now for guaranteed internship      1
# 4              Registration charges mandatory      1

# %%
X_train, X_test, y_train, y_test = train_test_split(
    df["text"], df["label"], test_size=0.2, random_state=42
)

# %%
vectorizer = TfidfVectorizer(
    stop_words='english',
    ngram_range=(1,3),
    max_features=7000
)

X_train_vec = vectorizer.fit_transform(X_train)
X_test_vec = vectorizer.transform(X_test)

# %%
model = LogisticRegression(
    class_weight='balanced',
    max_iter=1200
)

model.fit(X_train_vec, y_train)

y_pred = model.predict(X_test_vec)

print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:\n")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.9423076923076923
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.90      0.95        29
#            1       0.88      1.00      0.94        23
#
#     accuracy                           0.94        52
#    macro avg       0.94      0.95      0.94        52
# weighted avg       0.95      0.94      0.94        52

# %%
pickle.dump(model, open("model.pkl", "wb"))
pickle.dump(vectorizer, open("vectorizer.pkl", "wb"))

print("Model and vectorizer saved successfully!")
# Out:
# Model and vectorizer saved successfully!
